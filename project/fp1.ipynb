# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/home/rmfarizky/Hacktiv8-Learncode/dataset/rideshare_kaggle.csv")

# %%
pd.set_option("display.max_columns",None)

# %%
df
# Out:
#                                           id     timestamp  hour  day  month  \
# 0       424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1       4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2       981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3       c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4       e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
# ...                                      ...           ...   ...  ...    ...
# 693066  616d3611-1820-450a-9845-a9ff304a4842  1.543708e+09    23    1     12
# 693067  633a3fc3-1f86-4b9e-9d48-2b7132112341  1.543708e+09    23    1     12
# 693068  64d451d0-639f-47a4-9b7c-6fd92fbd264f  1.543708e+09    23    1     12
# 693069  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e  1.543708e+09    23    1     12
# 693070  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda  1.543708e+09    23    1     12
#
# ...

# %%
df.head()
# Out:
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
#
#               datetime          timezone            source    destination  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square  North Station
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square  North Station
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square  North Station
# 3  2018-11-30 04:53:02  America/New_York  Haymarket Square  North Station
# 4  2018-11-29 03:49:20  America/New_York  Haymarket Square  North Station
#
#   cab_type    product_id          name  price  distance  surge_multiplier  \
# ...

# %%
df.shape
# Out:
# (693071, 57)

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# price    55095
# dtype: int64

# %%
df["price"] = df["price"].fillna(df["price"].mean())

# %%
df = df.drop(["id","timestamp","datetime","timezone"],axis=1)

# %%
df
# Out:
#         hour  day  month            source    destination cab_type  \
# 0          9   16     12  Haymarket Square  North Station     Lyft
# 1          2   27     11  Haymarket Square  North Station     Lyft
# 2          1   28     11  Haymarket Square  North Station     Lyft
# 3          4   30     11  Haymarket Square  North Station     Lyft
# 4          3   29     11  Haymarket Square  North Station     Lyft
# ...      ...  ...    ...               ...            ...      ...
# 693066    23    1     12          West End      North End     Uber
# 693067    23    1     12          West End      North End     Uber
# 693068    23    1     12          West End      North End     Uber
# 693069    23    1     12          West End      North End     Uber
# 693070    23    1     12          West End      North End     Uber
#
#                                   product_id          name      price  \
# 0                                  lyft_line        Shared   5.000000
# ...

# %%
df.head()
# Out:
#    hour  day  month            source    destination cab_type    product_id  \
# 0     9   16     12  Haymarket Square  North Station     Lyft     lyft_line
# 1     2   27     11  Haymarket Square  North Station     Lyft  lyft_premier
# 2     1   28     11  Haymarket Square  North Station     Lyft          lyft
# 3     4   30     11  Haymarket Square  North Station     Lyft   lyft_luxsuv
# 4     3   29     11  Haymarket Square  North Station     Lyft     lyft_plus
#
#            name  price  distance  surge_multiplier  latitude  longitude  \
# 0        Shared    5.0      0.44               1.0   42.2148    -71.033
# 1           Lux   11.0      0.44               1.0   42.2148    -71.033
# 2          Lyft    7.0      0.44               1.0   42.2148    -71.033
# 3  Lux Black XL   26.0      0.44               1.0   42.2148    -71.033
# 4       Lyft XL    9.0      0.44               1.0   42.2148    -71.033
#
#    temperature  apparentTemperature    short_summary  \
# ...

# %%
#remove outliers pada kolom price dengan metode iqr 
price_q1 = df["price"].describe().loc["25%"]
price_q3 = df["price"].describe().loc["75%"]
price_iqr = price_q3 - price_q1

price_upper_bound = price_q3 + (1.5 * price_iqr)
price_lower_bound = price_q1 + (1.5 * price_iqr)

df_without_outliers = df[(df["price"]>= price_lower_bound)&(df['price']<= price_upper_bound)].copy()

# %%
from dython.nominal import associations

# %%
corr = associations(df_without_outliers)
# Out:
# /home/rmfarizky/micromamba/envs/hlc/lib/python3.11/site-packages/dython/nominal.py:708: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)
# /home/rmfarizky/micromamba/envs/hlc/lib/python3.11/site-packages/dython/nominal.py:709: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[j], columns[i]] = _inf_nan_str(ji)

# %%
top_10_corre = abs(corr["corr"][["price"]].drop("price")).sort_values('price',ascending=False).head(10)

# %%
fig = plt.figure(figsize=(10,4),dpi=200)

# %%
top_10_corre.sort_values("price").plot(
    kind='barh',
    legend=None,
    color='green',
    ax=plt.gca()
)
plt.title("Top 10 Features that have the Most Influence on Price")
plt.xlabel("Correlation Coefficient")
plt.show()

# %%
df_without_outliers = df_without_outliers[list(top_10_corre.index)+["price"]]
df_without_outliers
# Out:
#         distance    destination                   source  \
# 37          2.94         Fenway            North Station
# 80          3.39  North Station        Boston University
# 88          3.39  North Station        Boston University
# 93          2.82       West End                   Fenway
# 101         2.49       Back Bay            South Station
# ...          ...            ...                      ...
# 693011      2.44    Beacon Hill  Northeastern University
# 693017      2.88       Back Bay                North End
# 693024      2.50    Beacon Hill            South Station
# 693031      2.44    Beacon Hill  Northeastern University
# 693053      3.11         Fenway         Theatre District
#
#                                   product_id          name  surge_multiplier  \
# 37      6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV               1.0
# 80      6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV               1.0
# ...

# %% [markdown]
# # Data Eksplorasi

# %%
df_without_outliers.head()
# Out:
#      distance    destination             source  \
# 37       2.94         Fenway      North Station
# 80       3.39  North Station  Boston University
# 88       3.39  North Station  Boston University
# 93       2.82       West End             Fenway
# 101      2.49       Back Bay      South Station
#
#                                product_id          name  surge_multiplier  \
# 37   6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV               1.0
# 80   6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV               1.0
# 88   6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV               1.0
# 93                            lyft_luxsuv  Lux Black XL               1.0
# 101  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV               1.0
#
#     cab_type                                       long_summary  \
# 37      Uber                 Mostly cloudy throughout the day.
# 80      Uber                          Rain throughout the day.
# ...

# %%
uberx_lyft_price_mean = df_without_outliers[df_without_outliers["name"].isin(["UberX","Lyft"])]

# %%
df_without_outliers["price"] = pd.to_numeric(df_without_outliers["price"],errors="coerce")

# %%
df_without_outliers.dropna(subset=["price"],inplace=True)

# %%
uberx_lyft_price_mean.groupby(["name","distance"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/micromamba/envs/hlc/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~/micromamba/envs/hlc/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/micromamba/envs/hlc/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
# ...

# %%
uberx_lyft_price_mean
# Out:
#      name  distance  price
# 0    Lyft      3.23   34.0
# 1    Lyft      3.36   34.0
# 2    Lyft      3.74   30.0
# 3    Lyft      3.75   32.5
# 4    Lyft      4.39   38.5
# 5    Lyft      4.43   32.5
# 6    Lyft      4.57   32.5
# 7    Lyft      4.64   38.0
# 8    Lyft      4.70   32.5
# 9    Lyft      4.71   32.5
# 10   Lyft      4.72   32.5
# 11   Lyft      4.79   32.5
# 12   Lyft      4.96   30.0
# 13  UberX      1.89   32.0
# 14  UberX      3.35   30.5
# 15  UberX      3.40   29.5
# 16  UberX      3.42   41.5
# 17  UberX      4.30   36.5
# 18  UberX      4.70   32.0
# 19  UberX      4.80   30.5
# 20  UberX      4.90   29.5
# 21  UberX      5.56   29.0
# 22  UberX      7.18   35.0
# 23  UberX      7.19   30.5

# %%
uberx_lyft_price_mean = uberx_lyft_price_mean[
    uberx_lyft_price_mean["distance"].isin(
        set(
            list(uberx_lyft_price_mean[uberx_lyft_price_mean["name"] == "Lyft"]["distance"].unique())
        ).intersection(
            list(uberx_lyft_price_mean[uberx_lyft_price_mean["name"] == "UberX"]["distance"].unique())
        )
    )
]

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.lineplot(data=uberx_lyft_price_mean,x="distance",y="price",hue="name")
plt.title("Average Prices of UberX and Lyft")
plt.xlabel("Distance")
plt.ylabel("Price")
plt.legend(bbox_to_anchor=(1.02,0.5),loc="center left")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
uber_name = df_without_outliers[df_without_outliers["cab_type"] == "Uber"].groupby("name").sum()[["price"]].sort_values("price",ascending=False)
lyft_name = df_without_outliers[df_without_outliers["cab_type"] == "Lyft"].groupby("name").sum()[["price"]].sort_values("price",ascending=False)

# %%
fig, ax = plt.subplots(figsize=(10, 4), dpi=200, nrows=1, ncols=2)

# Assuming your data has 7 elements, adjust the explode accordingly
explode_values1 = [0.1]*len(uber_name)
explode_values2 = [0.1,]*len(lyft_name)

ax[0].pie(uber_name["price"], labels=uber_name.index, autopct="%.1f%%", explode=explode_values1, colors=sns.color_palette("Pastel1"))
ax[0].set_title("Uber")

ax[1].pie(lyft_name["price"], labels=lyft_name.index, autopct="%.1f%%", explode=explode_values2, colors=sns.color_palette("Pastel1"))
ax[1].set_title("Lyft")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder()
X = df_without_outliers.copy().drop("price",axis=1).apply(le.fit_transform)
y = df_without_outliers.copy()["price"]

# %%
X
# Out:
#         distance  destination  source  product_id  name  surge_multiplier  \
# 37           244            3       7           2     1                 0
# 80           289            7       2           2     1                 0
# 88           289            7       2           2     1                 0
# 93           232           11       3           8     4                 0
# 101          199            0       9           2     1                 0
# ...          ...          ...     ...         ...   ...               ...
# 693011       194            1       8           8     4                 0
# 693017       238            0       6           8     4                 0
# 693024       200            1       9           2     1                 0
# 693031       194            1       8           8     4                 0
# 693053       261            3      10           8     4                 0
#
#         cab_type  long_summary  short_summary  windSpeed
# ...

# %%
y
# Out:
# 37        29.5
# 80        34.0
# 88        36.0
# 93        32.5
# 101       32.5
#           ...
# 693011    30.0
# 693017    34.0
# 693024    29.0
# 693031    30.0
# 693053    32.5
# Name: price, Length: 61506, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1221)

print(f"Training dataset\t: {len(X_train)}")
print(f"Testing dataset\t\t: {len(X_test)}")
# Out:
# Training dataset	: 43054
# Testing dataset		: 18452

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# # Model Definition & Training

# %%
model = LinearRegression()

# %%
model.fit(scaled_X_train,y_train)
# Out:
# LinearRegression()

# %%
model_pred = model.predict(scaled_X_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test,model_pred)
# Out:
# 0.21006202159374054

# %%
from sklearn.preprocessing import PolynomialFeatures 

poly_4_X = PolynomialFeatures(degree=4,include_bias=False).fit_transform(X)

# %%
poly_4_X_train, poly_4_X_test, y_train, y_test = train_test_split(poly_4_X,y,test_size=0.3,random_state=1221)

scaled_poly_4_X_train =scaler.fit_transform(poly_4_X_train)
scaled_poly_4_X_test = scaler.transform(poly_4_X_test)

# %%
poly_4_model = LinearRegression()
poly_4_model.fit(scaled_poly_4_X_train,y_train)
# Out:
# LinearRegression()

# %%
poly_4_pred = poly_4_model.predict(scaled_poly_4_X_test)

# %%
r2_score(y_test, poly_4_pred)
# Out:
# -7.95893074826272e+18
